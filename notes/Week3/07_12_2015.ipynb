# %%
# %pylab inline
from IPython.core.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# 10 hour run with 0.5% perturbation but only stepped through 40 timesteps?

# %% [markdown]
# The time step becomes very small starting at:
#
# cycle=86924 time=4.40348487535697e+01 dt=4.26160597323911e-06
#
# Going all the way to e-12 , but I didn't observe high velocities anywhere , so I'm not sure what that's trying to reoslve.'

# %% [markdown]
# The last restart is at 34 so I only went on for t=10 for 10 hrs

# %% [raw]
# aprun -n 24 ../bin/athena -r ptrb_sphtorus.out2.00034.rst time/tlim=150  -i athinput.sphtorus

# %% [markdown]
# It is also reaching t_run since

# %%
8.5*2*pi
# Out:
# 53.40707511102649

# %%
Image(filename="../../../data/ptrb_sphtorus_last_timestep.png",width=500)

# %% [markdown]
# Doesn't look like anything has particularly high velocity except the center which started off at around 2 or so but went up to 3. '

# %% [markdown]
# Also continue running the first simulation and found that non axisymmetric strucutres begin to grow. Not too sure whether the orbital time count stops here? (i.e. is this already the nonlinear regime?)

# %%
Image(filename="../../../data/nonlinear.png",width=400)

# %%
Image(filename="../../../data/nonlinear2.png",width=500)

# %%
Image(filename="../../../data/nonlinear3.png",width=500)
