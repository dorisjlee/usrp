# %% [markdown]
# Note that the random initialization amplitude is set as 1% right now , if we want to model mode growth and have more datapoitns in the linear regime, we can crank down the amplitude to extend the linear time .

# %% [markdown]
# The log results are pretty good, we no longer hit the density floor. The timestep is not limited to t=199 because small scaled features near the inner boundary is more resolved resulting in less cells with high velocity

# %%
# %pylab inline
from IPython.core.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Image(filename="../Week4/img/log1_t210.png",width=500)

# %%
Image(filename="../Week4/img/log2_t120.png",width=500)

# %% [markdown]
# Velocities were also much lower
