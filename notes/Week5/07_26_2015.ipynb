# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Problem : unconnected magnetic field lines

# %%
from IPython.core.display  import Image

# %%
Image("mri1.png",width=500)

# %%
Image("mri2_hi_res.png",width=500)

# %%
Image("mri3_d0*1000.png",width=500)

# %%
Image("mri4_d_1_125.png",width=500)

# %%
Image("mri5d0_5000.png",width=500)

# %%
Image("dist1.5.png",width=500)

# %% [markdown]
# Changing the distortionparameter just maeks a wider torus but that doesn't really matter since the threshold is so high now '

# %% [markdown]
# Turning the density threshold back down to a factor of 1000

# %% [markdown]
# I think a larger distortion parameter is actually bad because it means that the inner radius is very triangular peaked so the field lines breaks there

# %%
Image("dist1.5_d0*1000.png",width=500)

# %% [markdown]
# So back to a fatter, rounder roturs , d = 1.125 and d0*2000

# %%
Image("good_ish.png" ,width=500)

# %% [markdown]
# There are still some unconnected fields but it is not entirely clear where its supposed to be connected to so I'll jsut leave it'

# %% [markdown]
# This still looks kind of weird at the later time steps

# %%
Image("t2.png" ,width=500)

# %% [markdown]
# Maybe Upping the resolution even more...

# %% [markdown]
# Oops just found out that I was using the wrong solver, I should be using HLLD

# %% [markdown]
# I tried looking at the processor info using

# %% [raw]
# aprun -n 96  ../bin/athena -m 96 athinput.sphtorus

# %% [markdown]
# Not sure if this is the right syntax`

# %% [markdown]
# # Making movie with VisIT

# %% [markdown]
# http://www.visitusers.org/index.php?title=Making_Movies#Making_movies_using_the_movie_script

# %%
visit -movie -fmt mpeg  -sessionfile gid_movie_zslice.session -adjustview -source /global/scratch2/sd/dorislee/athena_2/fixed_initialization/gid_random_init.out1.00*.ath.xdmf  -fps

# %%
It seems like visit has problem reading the time information from xdmf file
