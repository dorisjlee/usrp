# %% [markdown]
# ### Debugging code for pgen

# %% [markdown]
# - A3 = 0 as debugged printed, that's why B is zero
# - strangely density is also zero (torus no density?)'
# - eq29: -0 Not sure what negative zero mean but this is wrong...
# - This just prints for a long time and the eq20 is negative therefor it does not go in the density calculation

# %% [markdown]
# - B is non zero
# - density looks really werid
#
# cycle=0 time=0.00000000000000e+00 dt=8.53387308736893e-10
#
# cycle=1 time=8.53387308736893e-10 dt=7.79593802620294e-10

# %%
from IPython.core.display import Image

# %%
Image(filename="../Week5/weird_density.png",width=500)

# %% [markdown]
# fixed the magnetic pressure part in the boundary condition

# %% [markdown]
# - The B values are zero but this doesn't make sense because the B values taht I printed out is nonzero'

# %% [markdown]
# - The pressure also looks bad.

# %% [markdown]
# ### More debugging

# %% [markdown]
# At t=0
#
# $\rho$ looks okay

# %% [markdown]
# But B is really off

# %%
Image(filename="../Week5/weird_B.png",width=500)

# %% [markdown]
# B_mag,b_x1,b_x2 is correctly torus shape, so right magnitude but incorrect vectors

# %% [markdown]
# fixed the way the surface is defined in $B_r$

# %% [markdown]
# The bad thing is that after a while the B_r , $B_\theta$ turns into $B_\phi$ which is undesirable

# %%
Image(filename="../Week5/weirdB2.png",width=500)

# %% [raw]
# I tried going back to athena 4.2 sph to see what it would look like if I ran the original code in MHd but there's seg fault
#
# sphtorus_mhd> ../bin/athena -i athinput.sphtorus
# Simulation started on Fri Jul 24 15:19:07 2015
#
# Segmentation fault'
